# %% [markdown]
# <a href="https://colab.research.google.com/github/a-tale-of-data/mycolabprojects/blob/master/Welcome_to_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
img=cv.imread('happy.png',0)

# %%
plt.imshow(img,cmap='gray')
plt.show()
